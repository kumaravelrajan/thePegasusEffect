# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Using OS library to call CLI commands in Python
listOfJournos = ["ferdi_ayi", "khalafroula", "bradleyhope", "Khadija_Ismayil", "svaradarajan", 
                 "edwyplenel", "panyiszabolcs", "YuririaSierra", "Bagiruwubusa", "aristeguicnn", "vijaita", "paranjoygt", 
                 "aboubakrj", "LenaBred", "mkvenu1", "turankislakci", "Rosamoussaoui", "mariamoukrim", "jorgecarrascoa", 
                 "bainjal", "alexsicairosr", "Smita_Sharma", "xanic", "icembrero", "SushantSin", "MarocAmar", "marcelaturati", 
                 "carloskeiths", "ricardomraphael", "iftikhargilani", "JasurSumerinli", "rohini_sgh", "lhan55", "alvaro_delgado"]

#for journo in listOfJournos:
for journo in listOfJournos:
    os.system("snscrape --jsonl --since 2015-01-01 twitter-search \"from:" + journo + " until:2021-12-2\" > " + journo + "-query-tweets.json")
    
    # Reads the json generated from the CLI commands above and creates a pandas dataframe
    journo_tweets_df = pd.read_json(journo + '-query-tweets.json', lines=True)
    sample = journo_tweets_df['date']
    samplelist = list(sample)
    sampledict = {}

    for timestamp in samplelist:
        key = str(timestamp.year) + "-" + str(timestamp.month) # str(timestamp.year) + "-" + timestamp.month_name()
        if(sampledict.get(key) == None):
            sampledict[key] = 1
        else:
            sampledict[key] += 1
    #print(sampledict.keys())
    #print(sampledict.values())
    plt.title("Number of tweets by " + journo + " per month in 2021")
    plt.xlabel('Months')
    plt.ylabel('Number of tweets')
    plt.xticks(rotation="vertical")
    plt.bar(sampledict.keys(), sampledict.values())
    plt.show()
# Out:
# 2021-12-08 07:29:09.393  ERROR  snscrape.base  Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3Asvaradarajan+until%3A2021-12-2&tweet_search_mode=live&count=100&query_source=spelling_expansion_revert_click&cursor=scroll%3AthGAVUV0VFVBaAgLCl2_iK0BoWioCyrfH_-dgoEnEV3N9cFYCJehgHREVGQVVMVDUBFeASFQAA&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel: ConnectionError(MaxRetryError("HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3Asvaradarajan+until%3A2021-12-2&tweet_search_mode=live&count=100&query_source=spelling_expansion_revert_click&cursor=scroll%3AthGAVUV0VFVBaAgLCl2_iK0BoWioCyrfH_-dgoEnEV3N9cFYCJehgHREVGQVVMVDUBFeASFQAA&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fef827e6df0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))"))
# 2021-12-08 07:29:09.393  CRITICAL  snscrape.base  4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3Asvaradarajan+until%3A2021-12-2&tweet_search_mode=live&count=100&query_source=spelling_expansion_revert_click&cursor=scroll%3AthGAVUV0VFVBaAgLCl2_iK0BoWioCyrfH_-dgoEnEV3N9cFYCJehgHREVGQVVMVDUBFeASFQAA&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel failed, giving up.
# 2021-12-08 07:29:11.478  CRITICAL  snscrape._cli  Dumped stack and locals to /tmp/snscrape_locals_3devjz4e
# Traceback (most recent call last):
#   File "/home/kumar/.local/bin/snscrape", line 8, in <module>
#     sys.exit(main())
#   File "/home/kumar/.local/lib/python3.8/site-packages/snscrape/_cli.py", line 283, in main
#     for i, item in enumerate(scraper.get_items(), start = 1):
#   File "/home/kumar/.local/lib/python3.8/site-packages/snscrape/modules/twitter.py", line 556, in get_items
#     for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', params, paginationParams, cursor = self._cursor):
#   File "/home/kumar/.local/lib/python3.8/site-packages/snscrape/modules/twitter.py", line 250, in _iter_api_data
#     obj = self._get_api_data(endpoint, reqParams)
#   File "/home/kumar/.local/lib/python3.8/site-packages/snscrape/modules/twitter.py", line 220, in _get_api_data
#     r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = self._check_api_response)
#   File "/home/kumar/.local/lib/python3.8/site-packages/snscrape/base.py", line 204, in _get
#     return self._request('GET', *args, **kwargs)
#   File "/home/kumar/.local/lib/python3.8/site-packages/snscrape/base.py", line 200, in _request
#     raise ScraperException(msg)
# snscrape.base.ScraperException: 4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3Asvaradarajan+until%3A2021-12-2&tweet_search_mode=live&count=100&query_source=spelling_expansion_revert_click&cursor=scroll%3AthGAVUV0VFVBaAgLCl2_iK0BoWioCyrfH_-dgoEnEV3N9cFYCJehgHREVGQVVMVDUBFeASFQAA&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel failed, giving up.
